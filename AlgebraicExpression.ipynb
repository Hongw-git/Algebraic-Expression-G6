# %% [markdown]
# # Borb's  Algebraic Expression
# Students: Turkey, Dino, and !?#!
# ![Whitey-2.JPG](attachment:Whitey-2.JPG)

# %%
from IPython.display import Image
Image(url="https://i.pinimg.com/originals/7b/7f/8b/7b7f8ba7ad3381f8cfd4f9ef9a6bec48.png", width=200, height=200)
# Out:
# <img src="https://i.pinimg.com/originals/7b/7f/8b/7b7f8ba7ad3381f8cfd4f9ef9a6bec48.png" width="200" height="200"/>

# %% [markdown]
# Q1. Alex weighs $x$ lbs, and mom weighs twice the weight of Alex minus 50 lbs. How heavy is Mom?
# 1. Write the algebraic expression of Mom's weight
# 2. If x=90, what is mom's weight

# %% [markdown]
# Mom's weight = 2x-50

# %%
###answer
x=90
y=2*x-50
print("Mom's weight is",y)
# Out:
# Mom's weight is 130

# %% [markdown]
# Turkey is confused. Borb asks her to watch the videl below.

# %%
###insert Youtube vedio
import IPython
from IPython.display import YouTubeVideo

YouTubeVideo('fUOdon3y1hU', width=800, height=300)

# %% [markdown]
# Q2. Alex earns $x$ dollars, and Jeff earns $30$ dollars. The total of their earnings is 100.
# 1. Write down the equation.
# 2. How much does Alex earn?

# %% [markdown]
# x+30=100

# %%
#answer
x=100-30
print('Alex earns', x)
# Out:
# Alex earns 70

# %% [markdown]
# Dino needs help with equation. Please watch the video below.

# %%
YouTubeVideo('fUOdon3y1hU', width=800, height=300)

# %% [markdown]
# # Borb now asks Dino to give a few questions for Turkey.
# Please write down your questions below.

# %%
###useful video ###https://www.youtube.com/watch?v=_Nbvgwe3JC0&list=PL2Xn_exqSLLiF2nmxBtuEmVKwQqmKoflh&index=50&t=2s
YouTubeVideo('_Nbvgwe3JC0&list=PL2Xn_exqSLLiF2nmxBtuEmVKwQqmKoflh&index=50&t=2s', width=800, height=300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="https://www.youtube.com/embed/_Nbvgwe3JC0&list=PL2Xn_exqSLLiF2nmxBtuEmVKwQqmKoflh&index=50&t=2s"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
